# %%
# %pylab inline

# %%
import dataiku
from dataiku import pandasutils as pdu
import pandas as pd

# %%
# Example: load a DSS dataset as a Pandas dataframe
mydataset = dataiku.Dataset("mydataset")
mydataset_df = mydataset.get_dataframe()

# %%
client = dataiku.api_client()

# %%
s = client.get_general_settings()

# %%
s.__dict__
# Out:
# {'client': <dataikuapi.dssclient.DSSClient at 0x7faebc41bed0>,
#  'settings': {u'achievementsDisabled': False,
#   u'alationSettings': {u'enabled': False},
#   u'apiDeployerClientSettings': {u'mode': u'LOCAL'},
#   u'apiDeployerServerSettings': {u'serverEnabledDespiteRemote': False,
#    u'stages': [{u'desc': u'For applications development',
#      u'id': u'Development'},
#     {u'desc': u'Acceptance testing', u'id': u'Test'},
#     {u'desc': u'Running live for users', u'id': u'Production'}]},
#   u'auditTrailSettings': {u'targets': [{u'appendTopicToLogger': True,
#      u'routingKeys': [],
#      u'routingKeysFiltering': u'ALL',
#      u'topics': [],
#      u'topicsFiltering': u'ALL',
#      u'type': u'LOG4J'}]},
#   u'cgroupSettings': {u'cgroups': [],
#    u'eda': {u'targets': []},
#    u'enabled': False,
#    u'hierarchiesMountPoint': u'/sys/fs/cgroup',
#    u'jupyterKernels': {u'targets': []},
#    u'mlKernels': {u'targets': []},
#    u'mlRecipes': {u'targets': []},
#    u'pythonMacros': {u'targets': []},
#    u'pythonRRecipes': {u'targets': []},
#    u'pythonRSparkRecipes': {u'targets': []},
#    u'rmarkdownBuilders': {u'targets': []},
#    u'webappDevBackends': {u'targets': []}},
#   u'codeEnvs': {u'condaCreateExtraOptions': [],
#    u'condaInstallExtraOptions': [],
#    u'cranMirrorURL': u'https://cloud.r-project.org',
#    u'pipInstallExtraOptions': [],
#    u'virtualenvCreateExtraOptions': []},
#   u'computablesAvailabilityMode': u'EXPOSED_ONLY',
#   u'computeResourceUsageReportingSettings': {u'includeBuiltinCluster': False,
#    u'namespacePattern': u'^(?!kube-).*',
#    u'periodicKubernetesUsageReporting': False},
#   u'containerSettings': {u'defaultWebappsK8SExposition': {u'params': {},
#     u'type': u'port_forward'},
#    u'executionConfigs': [{u'allowedGroups': [],
#      u'baseImage': u'',
#      u'baseImageType': u'EXEC',
#      u'createNamespace': False,
#      u'dockerNetwork': u'host',
#      u'dockerResources': [],
#      u'dockerTLSVerify': False,
#      u'ensureNamespaceCompliance': False,
#      u'hostPathVolumes': [],
#      u'isFinal': False,
#      u'kubernetesResources': {u'cpuLimit': -1.0,
#       u'cpuRequest': -1.0,
#       u'customLimits': [],
#       u'customRequests': [],
#       u'memLimitMB': -1,
#       u'memRequestMB': -1},
#      u'name': u'k8s-pmp-config-demo1',
#      u'prePushMode': u'ECR',
#      u'properties': [],
#      u'repositoryURL': u'401293328855.dkr.ecr.us-east-2.amazonaws.com/pmp-test',
#      u'type': u'KUBERNETES',
#      u'usableBy': u'ALL'},
#     {u'allowedGroups': [],
#      u'baseImageType': u'EXEC',
#      u'createNamespace': False,
#      u'dockerNetwork': u'host',
#      u'dockerResources': [],
#      u'dockerTLSVerify': False,
#      u'ensureNamespaceCompliance': False,
#      u'hostPathVolumes': [],
#      u'isFinal': False,
#      u'kubernetesResources': {u'cpuLimit': 6.0,
#       u'cpuRequest': 4.0,
#       u'customLimits': [],
#       u'customRequests': [],
#       u'memLimitMB': 36000,
#       u'memRequestMB': 30000},
#      u'name': u'k8s-large',
#      u'prePushMode': u'ECR',
#      u'properties': [],
#      u'repositoryURL': u'401293328855.dkr.ecr.us-east-2.amazonaws.com/pmp-test',
#      u'type': u'KUBERNETES',
#      u'usableBy': u'ALL'},
#     {u'allowedGroups': [],
#      u'baseImage': u'dku-exec-base-prodaps-v1:dss-8.0.1',
#      u'baseImageType': u'EXEC',
#      u'createNamespace': False,
#      u'dockerNetwork': u'host',
#      u'dockerResources': [],
#      u'dockerTLSVerify': False,
#      u'ensureNamespaceCompliance': False,
#      u'hostPathVolumes': [],
#      u'isFinal': False,
#      u'kubernetesResources': {u'cpuLimit': -1.0,
#       u'cpuRequest': -1.0,
#       u'customLimits': [],
#       u'customRequests': [],
#       u'memLimitMB': -1,
#       u'memRequestMB': -1},
#      u'name': u'k8s-prodaps',
#      u'prePushMode': u'ECR',
#      u'properties': [],
#      u'repositoryURL': u'401293328855.dkr.ecr.us-east-2.amazonaws.com/pmp-test',
#      u'type': u'KUBERNETES',
#      u'usableBy': u'ALL'}],
#    u'executionConfigsGenericOverrides': {u'allowedGroups': [],
#     u'baseImageType': u'EXEC',
#     u'createNamespace': False,
#     u'dockerNetwork': u'host',
#     u'dockerResources': [],
#     u'dockerTLSVerify': False,
#     u'ensureNamespaceCompliance': False,
#     u'hostPathVolumes': [],
#     u'isFinal': False,
#     u'kubernetesResources': {u'cpuLimit': -1.0,
#      u'cpuRequest': -1.0,
#      u'customLimits': [],
#      u'customRequests': [],
#      u'memLimitMB': -1,
#      u'memRequestMB': -1},
#     u'prePushMode': u'NONE',
#     u'properties': [],
#     u'usableBy': u'ALL'}},
#   u'corsSettings': {u'accessControlAllowCredentials': False,
#    u'accessControlAllowHeaders': [],
#    u'accessControlAllowMethods': [],
#    u'accessControlAllowOriginRegExps': [],
#    u'accessControlExposeHeaders': []},
#   u'customFieldsPluginComponentOrder': [],
#   u'customPolicyHooksPluginComponentOrder': [],
#   u'debounceDelayForWikiArticleSave': 300000,
#   u'defaultDatasetCreationSettings': {u'allowUploadsWithoutConnection': True,
#    u'preferedStorageFormats': u'CSV_ESCAPING_NOGZIP_FORHIVE,CSV_EXCEL_GZIP,PARQUET_HIVE',
#    u'virtualizable': False},
#   u'defaultK8sClusterId': u'pmp-eks-cluster-demo4',
#   u'defaultRecipeCreationSettings': {u'prepareRecipeColumnTypeMode': u'ALWAYS_INFER'},
#   u'disableAutomaticTriggers': False,
#   u'dropDataWithDatasetDeleteEnabled': False,
#   u'eventServerSettings': {u'eventsAuthenticationKeys': [],
#    u'queueSize': 5000,
#    u'requireAuthenticationForEvents': False,
#    u'requireAuthenticationForStats': False,
#    u'statsAuthenticationKeys': [],
#    u'targets': []},
#   u'generateInitialPassword': False,
#   u'git': {u'enforcedConfigurationRules': [{u'allowGit': True,
#      u'dssControlsSSHCommand': True,
#      u'gitConfigurationOptions': [],
#      u'remoteWhitelist': [u'^(?:git|ssh|https?|git@[-\\w.]+):(\\/\\/)?(.*?)(\\.git)?(\\/?|\\#[-\\d\\w._]+?)$']}]},
#   u'globalCrossProjectBuildBehaviour': u'STOP_AT_BOUNDARIES',
#   u'globalTagsCategories': [],
#   u'graphicsExportsEnabled': False,
#   u'graphiteReportingDelay': 0,
#   u'hadoopSettings': {u'extraConf': [],
#    u'kerberosLoginEnabled': False,
#    u'validationKernelsExtraEnv': []},
#   u'helpIntegrationEnabled': True,
#   u'hiveSettings': {u'addCompressionCommands': False,
#    u'addWriteACLOnDataUsabilityACL': False,
#    u'additionalUserToGrantAccessToWhenImpersonating': u'hive',
#    u'canChart': False,
#    u'configForHiveRuntime': u'default',
#    u'connectionProperties': [],
#    u'enabled': True,
#    u'engineCreationSettings': {u'executionEngine': u'HIVECLI_LOCAL'},
#    u'executionConfigs': [{u'conf': [], u'name': u'default'}],
#    u'executionConfigsGenericOverrides': [],
#    u'hiveServer2Host': u'127.0.0.1',
#    u'hiveServer2Port': 10000,
#    u'overrideDatabaseInLocalMetastore': False,
#    u'preCreateManagedDatasetFolderBeforeMetastoreSyncForHS2Recipes': True,
#    u'preCreateManagedDatasetFolderBeforeMetastoreSyncForMUSHS2Recipes': False,
#    u'useURL': False},
#   u'homeMessages': [],
#   u'impalaSettings': {u'additionalUserToGrantAccessToWhenImpersonating': u'impala',
#    u'authBehavior': u'KERBEROS_FALLBACK_NOAUTH',
#    u'connectionProperties': [],
#    u'credentialsMode': u'GLOBAL',
#    u'datanodes': [],
#    u'enabled': False,
#    u'engineCreationSettings': {u'streamMode': True},
#    u'isSelfSigned': False,
#    u'port': 21050,
#    u'preCreateManagedDatasetFolderBeforeMetastoreSyncForDirectWriteRecipes': True,
#    u'useSimbaDriver': False,
#    u'useSsl': False,
#    u'useURL': False},
#   u'impersonation': {u'enabled': False,
#    u'groupRules': [],
#    u'useHadoopDelegationTokens': True,
#    u'userRules': []},
#   u'internalDatabase': {u'builtinConnectionsMaxIdleTimeMS': 1800000,
#    u'builtinConnectionsValidationIntervalMS': 600000,
#    u'externalConnectionsMaxIdleTimeMS': 600000,
#    u'externalConnectionsValidationIntervalMS': 180000,
#    u'maxPooledBuiltinConnectionsPerDatabase': 50,
#    u'maxPooledExternalConnections': 50},
#   u'isAWSMarketplace': False,
#   u'k8sPoliciesSettings': {u'policies': []},
#   u'ldapSettings': {u'autoImportUsers': True,
#    u'defaultUserProfile': u'READER',
#    u'displayNameAttribute': u'cn',
#    u'emailAttribute': u'mail',
#    u'enableGroups': True,
#    u'enabled': False,
#    u'groupFilter': u'(&(objectClass=posixGroup)(memberUid={USERNAME}))',
#    u'groupNameAttribute': u'cn',
#    u'groupProfiles': [],
#    u'useTls': False,
#    u'userFilter': u'(&(objectClass=posixAccount)(uid={USERNAME}))'},
#   u'limits': {u'attachmentBytes': {u'hard': -1, u'soft': -1},
#    u'memSampleBytes': {u'hard': 524288000, u'soft': 104857600},
#    u'shakerMemTableBytes': {u'hard': 524288000, u'soft': -1}},
#   u'mailSettings': {},
#   u'maxRunningActivities': 8,
#   u'maxRunningActivitiesPerJob': 8,
#   u'maxRunningActivitiesPerKey': [],
#   u'metastoreCatalogsSettings': {u'synchronizeTo': {u'flavor': u'HIVESERVER2',
#     u'glueCredentialsMode': u'DEFAULT'}},
#   u'noLoginMode': False,
#   u'notifications': {u'notifyOnTaskStartAndStop': u'ALL_WITH_ACCESS_TO_PROJECT',
#    u'notifyOnUserConnection': u'ALL'},
#   u'npsSurveyEnabled': True,
#   u'personalHomePages': {u'articles': []},
#   u'pluginDevExplicitCommit': False,
#   u'projectStatusList': [{u'color': u'#4285F4', u'name': u'Sandbox'},
#    {u'color': u'#77bec2', u'name': u'Draft'},
#    {u'color': u'#94BF51', u'name': u'In use'},
#    {u'color': u'#ee874a', u'name': u'In production'},
#    {u'color': u'#CCCCCC', u'name': u'Archived'}],
#   u'proxySettings': {u'port': 0},
#   u'recipeEnginesPreferences': {u'enginesPreferenceOrder': [],
#    u'forbiddenByRecipeType': {},
#    u'forbiddenEngines': [],
#    u'preferenceByRecipeType': {}},
#   u'security': {u'caseSensitiveLogins': True,
#    u'forceSingleSessionPerUser': False,
#    u'hideErrorStacks': False,
#    u'hideVersionStringsWhenNotLogged': False,
#    u'postLogoutBehavior': u'LOGGED_OUT_PAGE',
#    u'restrictEasterEggsEvenForAdmin': False,
#    u'restrictUsersAndGroupsVisibility': False,
#    u'secureCookies': False,
#    u'secureSecretKeys': True,
#    u'sessionsMaxIdleTimeMinutes': 0,
#    u'sessionsMaxTotalTimeMinutes': 0,
#    u'webappsIsolationMode': u'NONE'},
#   u'sparkSettings': {u'additionalSparkSubmitJars': [],
#    u'configForInteractive': u'default',
#    u'configForJupyter': u'prodaps-spark-k8s-config',
#    u'configForSEK': u'default',
#    u'databricksSettings': {u'credentialsMode': u'GLOBAL',
#     u'enabled': False,
#     u'jdbcPathMidfix': u'0',
#     u'uploadSettings': {u'unsafeDirectUploadToDBFS': False},
#     u'userSpecificClusters': False},
#    u'engineCreationSettings': {u'executionConfig': u'prodaps-spark-k8s-config',
#     u'executionEngine': u'SPARK_SUBMIT',
#     u'useGlobalMetastore': True},
#    u'environmentVariables': [],
#    u'executionConfigs': [{u'cloudCredentialsSettings': {u'aws': {u'connections': [u'pmasiphelps-emr-dataiku-demo2'],
#        u'mode': u'FIRST_MATCH',
#        u'provideGlueClientCredential': True},
#       u'azure': {u'connections': [],
#        u'mode': u'NONE',
#        u'provideGlueClientCredential': True},
#       u'enabled': True,
#       u'gcp': {u'connections': [],
#        u'mode': u'NONE',
#        u'provideGlueClientCredential': True}},
#      u'conf': [{u'isFinal': False,
#        u'key': u'spark.executor.memory',
#        u'secret': False,
#        u'value': u'1g'},
#       {u'isFinal': False,
#        u'key': u'spark.executor.instances',
#        u'secret': False,
#        u'value': u'2'},
#       {u'isFinal': False,
#        u'key': u'spark.executor.cores',
#        u'secret': False,
#        u'value': u'1'}],
#      u'databricksClusterDef': {u'autotermination_minutes': 120,
#       u'num_workers': 2,
#       u'spark_version': u'5.5.x-scala2.11'},
#      u'description': u'This default configuration sets a few parameters that are suitable for a wide range of use cases.\n\nImportantly, in order to work in all circumstances, it does not set the spark master configuration.\nIt will thus use the master defined by your default Spark configuration. This may lead Spark jobs to execute locally, without using your cluster. You may need for example to add spark.master=yarn-client',
#      u'kubernetesSettings': {u'authenticationMode': u'BUILTIN',
#       u'baseImageType': u'SPARK',
#       u'createNamespace': True,
#       u'dockerTLSVerify': False,
#       u'ensureNamespaceCompliance': True,
#       u'managedKubernetes': True,
#       u'managedNamespace': u'dssns-${dssUserLogin}',
#       u'prePushMode': u'ECR',
#       u'repositoryURL': u'401293328855.dkr.ecr.us-east-2.amazonaws.com/pmp-test'},
#      u'name': u'k8s-config-standard'},
#     {u'cloudCredentialsSettings': {u'aws': {u'connections': [],
#        u'mode': u'NONE',
#        u'provideGlueClientCredential': True},
#       u'azure': {u'connections': [],
#        u'mode': u'NONE',
#        u'provideGlueClientCredential': True},
#       u'enabled': False,
#       u'gcp': {u'connections': [],
#        u'mode': u'NONE',
#        u'provideGlueClientCredential': True}},
#      u'conf': [{u'isFinal': False,
#        u'key': u'spark.master',
#        u'secret': False,
#        u'value': u'local[4]'},
#       {u'isFinal': False,
#        u'key': u'spark.driver.memory',
#        u'secret': False,
#        u'value': u'3g'},
#       {u'isFinal': False,
#        u'key': u'spark.sql.shuffle.partitions',
#        u'secret': False,
#        u'value': u'40'}],
#      u'databricksClusterDef': {u'autotermination_minutes': 120,
#       u'num_workers': 2,
#       u'spark_version': u'5.5.x-scala2.11'},
#      u'description': u'This sample configuration shows a possible set of parameters for running DSS Spark jobs locally (non distributed).\n\nThis can be useful for testing on small jobs, as local Spark jobs start faster than YARN ones, but is not suitable for production usage',
#      u'kubernetesSettings': {u'authenticationMode': u'BUILTIN',
#       u'baseImageType': u'SPARK',
#       u'createNamespace': False,
#       u'dockerTLSVerify': False,
#       u'ensureNamespaceCompliance': False,
#       u'managedKubernetes': False,
#       u'managedNamespace': u'default',
#       u'prePushMode': u'NONE'},
#      u'name': u'sample-local-config'},
#     {u'cloudCredentialsSettings': {u'aws': {u'connections': [u'pmasiphelps-emr-dataiku-demo2'],
#        u'mode': u'FIRST_MATCH',
#        u'provideGlueClientCredential': True},
#       u'azure': {u'connections': [],
#        u'mode': u'NONE',
#        u'provideGlueClientCredential': True},
#       u'enabled': True,
#       u'gcp': {u'connections': [],
#        u'mode': u'NONE',
#        u'provideGlueClientCredential': True}},
#      u'conf': [{u'isFinal': False,
#        u'key': u'spark.executor.memory',
#        u'secret': False,
#        u'value': u'1g'},
#       {u'isFinal': False,
#        u'key': u'spark.executor.instances',
#        u'secret': False,
#        u'value': u'2'},
#       {u'isFinal': False,
#        u'key': u'spark.executor.cores',
#        u'secret': False,
#        u'value': u'1'}],
#      u'databricksClusterDef': {u'autotermination_minutes': 120,
#       u'node_type_id': u'i3.xlarge',
#       u'num_workers': 2,
#       u'spark_version': u'4.3.x-scala2.11'},
#      u'kubernetesSettings': {u'authenticationMode': u'BUILTIN',
#       u'baseImage': u'dku-spark-base-prodaps-v1:dss-8.0.1',
#       u'baseImageType': u'SPARK',
#       u'createNamespace': True,
#       u'dockerTLSVerify': False,
#       u'ensureNamespaceCompliance': True,
#       u'managedKubernetes': True,
#       u'managedNamespace': u'dssns-${dssUserLogin}',
#       u'prePushMode': u'ECR',
#       u'repositoryURL': u'401293328855.dkr.ecr.us-east-2.amazonaws.com/pmp-test'},
#      u'name': u'prodaps-spark-k8s-config'},
#     {u'cloudCredentialsSettings': {u'aws': {u'connections': [u'pmasiphelps-emr-dataiku-demo2'],
#        u'mode': u'FIRST_MATCH',
#        u'provideGlueClientCredential': True},
#       u'azure': {u'connections': [],
#        u'mode': u'NONE',
#        u'provideGlueClientCredential': True},
#       u'enabled': True,
#       u'gcp': {u'connections': [],
#        u'mode': u'NONE',
#        u'provideGlueClientCredential': True}},
#      u'conf': [{u'isFinal': False,
#        u'key': u'spark.executor.memory',
#        u'secret': False,
#        u'value': u'1g'},
#       {u'isFinal': False,
#        u'key': u'spark.executor.instances',
#        u'secret': False,
#        u'value': u'2'},
#       {u'isFinal': False,
#        u'key': u'spark.executor.cores',
#        u'secret': False,
#        u'value': u'1'}],
#      u'databricksClusterDef': {u'autotermination_minutes': 120,
#       u'node_type_id': u'i3.xlarge',
#       u'num_workers': 2,
#       u'spark_version': u'4.3.x-scala2.11'},
#      u'kubernetesSettings': {u'authenticationMode': u'BUILTIN',
#       u'baseImage': u'dku-spark-base-ffmpeg:dss-8.0.1',
#       u'baseImageType': u'SPARK',
#       u'createNamespace': True,
#       u'dockerTLSVerify': False,
#       u'ensureNamespaceCompliance': True,
#       u'managedKubernetes': True,
#       u'managedNamespace': u'dssns-${dssUserLogin}',
#       u'prePushMode': u'ECR',
#       u'repositoryURL': u'401293328855.dkr.ecr.us-east-2.amazonaws.com/pmp-test'},
#      u'name': u'ffmpeg-spark-k8s-config'}],
#    u'executionConfigsGenericOverrides': [],
#    u'interactiveExecutionEngine': u'SPARK_SUBMIT',
#    u'livy': {u'additionalUserToGrantAccessToWhenImpersonating': u'livy',
#     u'auth': u'NONE',
#     u'blacklistedProperties': u'spark.master,spark.submit.deployMode,spark.yarn.jar,spark.yarn.jars,spark.yarn.archive,livy.rsc.server.idle-timeout',
#     u'connectionProperties': [],
#     u'enabled': False,
#     u'fetchSize': 1000,
#     u'host': u'127.0.0.1',
#     u'port': 8998,
#     u'protocol': u'HTTP',
#     u'useURL': False,
#     u'useYarnCluster': True},
#    u'sparkEnabled': True,
#    u'useNativeProcessors': True,
#    u'yarnClusterSettings': {}},
#   u'ssoSettings': {u'enabled': False,
#    u'protocol': u'SAML',
#    u'remappingRules': [],
#    u'spnegoMode': u'PREAUTH_KEYTAB',
#    u'spnegoStripRealm': True},
#   u'triggerCountdownDuration': 60,
#   u'udr': True,
#   u'variablesUpdateConfig': {u'globalVariablesCode': u''},
#   u'virtualWebAppBackendSettings': {u'infra': {u'containerSelection': {u'containerMode': u'INHERIT'},
#     u'deploymentModifier': {},
#     u'exposition': {u'params': {}, u'type': u'local_process'},
#     u'overrideGlobalK8sExposition': False,
#     u'scaling': {u'hpa': False,
#      u'hpaAnnotations': [],
#      u'hpaMaxPods': 0,
#      u'hpaMetrics': [],
#      u'hpaMinPods': 0,
#      u'hpaTargetCPUPercent': 0,
#      u'initialReplicas': 1}},
#    u'mode': u'USE_DEFAULT',
#    u'preventOverride': False},
#   u'webAppSecuritySettings': {u'accessTokenWhitelist': [],
#    u'disableAccessToken': False,
#    u'requiredAuthenticationMode': u'ALL_BUT_ADMIN_WHITELIST',
#    u'requiredAuthenticationWhitelist': [u'OPTIONGANSDEV.eZEVzVe'],
#    u'vanityURLs': []}}}
